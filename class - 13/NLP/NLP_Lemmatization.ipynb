# %% [markdown]
# # ***Lemmatization***
# ***Lemmatization reduces words to their base word, which is linguistically correct lemmas. It transforms root word with the use of vocabulary and morpholoaical analvsis***
# # ***Lemmatization: Finding the same root***
# *   Input : (Sings, Sung, Sang)
# *   Output : Sing

# %% [markdown]
# ## ***https://wordnet.princeton.edu/***

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()

# %% [markdown]
# # ***Remove the s or es and finding the root***

# %%
print("rocks :", lem.lemmatize("rocks"))
print("bues :", lem.lemmatize("buses"))
print("students :", lem.lemmatize("students"))
print("computers :", lem.lemmatize("computers"))
print("goes :", lem.lemmatize("goes"))
print("languages :", lem.lemmatize("languages"))
# Out:
# rocks : rock
# bues : bus
# students : student
# computers : computer
# goes : go
# languages : language

# %% [markdown]
# # ***Lematize the verd with argument***

# %%
word ="flying"
print("Lemmatization:" +word+"-->",lem.lemmatize(word,'v'))
# Out:
# Lemmatization:flying--> fly

# %%
word ="swiming"
print("Lemmatization:" +word+"-->",lem.lemmatize(word,'v'))
word ="educated"
print("Lemmatization:" +word+"-->",lem.lemmatize(word,'v'))
word ="had"
print("Lemmatization:" +word+"-->",lem.lemmatize(word,'v'))
# Out:
# Lemmatization:swiming--> swim
# Lemmatization:educated--> educate
# Lemmatization:had--> have

# %% [markdown]
# # ***Lematize the adjective with argument***

# %%
word ="better"
print("Lemmatization:" +word+"-->",lem.lemmatize(word,'a'))
word ="worst"
print("Lemmatization:" +word+"-->",lem.lemmatize(word,'a'))
# Out:
# Lemmatization:better--> good
# Lemmatization:worst--> bad

# %%
word ="taller"
print("Lemmatization:" +word+"-->",lem.lemmatize(word,'a'))
# Out:
# Lemmatization:taller--> tall
