# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4edfd446-ddb4-4c04-8477-191acc11ac36" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4edfd446-ddb4-4c04-8477-191acc11ac36">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df =pd.read_excel("shop.xlsx")

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.info() # we can find out all the information with datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Marketing Spend  50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Transport        49 non-null     float64
#  3   Area             50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.isnull()
# Out:
#     Marketing Spend  Administration  Transport   Area  Profit
# 0             False           False      False  False   False
# 1             False           False      False  False   False
# 2             False           False      False  False   False
# 3             False           False      False  False   False
# 4             False           False      False  False   False
# 5             False           False      False  False   False
# 6             False           False      False  False   False
# 7             False           False      False  False   False
# 8             False           False      False  False   False
# 9             False           False      False  False   False
# 10            False           False      False  False   False
# 11            False           False      False  False   False
# 12            False           False      False  False   False
# 13            False           False      False  False   False
# ...

# %%
df.isnull().sum() #summary of null value
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %% [markdown]
# # ***Measures of Central Tendency***

# %%
df.Transport.mean() #To see mean
# Out:
# np.float64(215331.7324489796)

# %%
df.Transport.median() #To see median
# Out:
# 214634.81

# %%
df.Transport.mode() #To see mode
# Out:
# 0    0.0
# Name: Transport, dtype: float64

# %%
df.Area.mode()
# Out:
# 0      Ctg
# 1    Dhaka
# Name: Area, dtype: object

# %%
df.describe()
# Out:
#        Marketing Spend  Administration      Transport         Profit
# count        50.000000       50.000000      49.000000      50.000000
# mean      73721.615600   121344.639600  215331.732449  112012.639200
# std       45902.256482    28017.802755  119665.391550   40306.180338
# min           0.000000    51283.140000       0.000000   14681.400000
# 25%       39936.370000   103730.875000  134050.070000   90138.902500
# 50%       73051.080000   122699.795000  214634.810000  107978.190000
# 75%      101602.800000   144842.180000  299737.290000  139765.977500
# max      165349.200000   182645.560000  471784.100000  192261.830000

# %% [markdown]
# # ***Data Visualization Using Seaborn***

# %%
# !pip install seaborn

# %%
import seaborn as sns #seaborn is a visualization library

# %%
sns.histplot(df[["Transport"]])
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(df[["Profit"]]) #histogram
# Out:
# <Axes: ylabel='Count'>

# %%
df_numeric = df.select_dtypes(include='number')  # filter numeric columns only
df_numeric.corr() #find the correlation
# Out:
#                  Marketing Spend  Administration  Transport    Profit
# Marketing Spend         1.000000        0.230437   0.718574  0.937948
# Administration          0.230437        1.000000   0.009534  0.200717
# Transport               0.718574        0.009534   1.000000  0.782578
# Profit                  0.937948        0.200717   0.782578  1.000000

# %%
plt.figure(figsize=(6,6))
sns.heatmap(df_numeric.corr()) #create heatmap from correlation
# Out:
# <Axes: >

# %%
matrix=df.copy()

# %%
matrix.drop("Area",axis=1,inplace=True)

# %%
matrix.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0        114523.61       136897.80  471784.10  192261.83
# 1        162597.70       151377.59  443898.53  191792.06
# 2        153441.51       101145.55  407934.54  191050.39
# 3        144372.41       118671.85  383199.62  182901.99
# 4        142107.34        91391.77  366168.42  166187.94

# %%
matrix.corr() #find correlation
# Out:
#                  Marketing Spend  Administration  Transport    Profit
# Marketing Spend         1.000000        0.230437   0.718574  0.937948
# Administration          0.230437        1.000000   0.009534  0.200717
# Transport               0.718574        0.009534   1.000000  0.782578
# Profit                  0.937948        0.200717   0.782578  1.000000

# %%
sns.heatmap(matrix.corr(),annot=True)
plt.savefig("heatmap.png")

# %% [markdown]
# both process can be works same

# %% [markdown]
# # ***Handle NAN/NULL value***

# %%
# best way to handle Null Value is replace the valu with somthing else(Here we will replace with mean value)
Mean_Transport =df.Transport.mean()

# %%
Mean_Transport
# Out:
# np.float64(215331.7324489796)

# %%
df.Transport = df.Transport.fillna(Mean_Transport) # .fillna() works to replace the null value with Mean_Transport

# %%
df.Transport
# Out:
# 0     471784.100000
# 1     443898.530000
# 2     407934.540000
# 3     383199.620000
# 4     366168.420000
# 5     362861.360000
# 6     127716.820000
# 7     323876.680000
# 8     311613.290000
# 9     304981.620000
# 10    229160.950000
# 11    249744.550000
# 12    249839.440000
# 13    252664.930000
# 14    256512.920000
# 15    261776.230000
# 16    264346.060000
# 17    282574.310000
# 18    294919.570000
# 19    215331.732449
# 20    298664.470000
# 21    299737.290000
# 22    303319.260000
# 23    304768.730000
# 24    140574.810000
# 25    137962.620000
# 26    134050.070000
# 27    353183.810000
# 28    118148.200000
# 29    107138.380000
# 30     91131.240000
# 31     88218.230000
# 32     46085.250000
# 33    214634.810000
# 34    210797.670000
# 35    205517.640000
# 36    201126.820000
# 37    197029.420000
# 38    185265.100000
# 39    174999.300000
# 40    172795.670000
# 41    164470.710000
# 42    148001.110000
# 43     35534.170000
# 44     28334.720000
# ...

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          0
# Area               0
# Profit             0
# dtype: int64

# %%
df.iloc[18:20] #to see the value of 18 and 19
# Out:
#     Marketing Spend  Administration      Transport     Area     Profit
# 18         91749.16       114175.79  294919.570000  Rangpur  124266.90
# 19         86419.70       153514.11  215331.732449    Dhaka  122776.86

# %%
# copying the data set
df1=df.copy()
df2=df.copy()
df3=df.copy()
df4=df.copy()
df5=df.copy()
df6=df.copy()
df7=df.copy()
df8=df.copy()
df9=df.copy()
df10=df.copy()
df11=df.copy()
df12=df.copy()

# %%
df.Transport.iloc[19]
# Out:
# np.float64(215331.7324489796)

# %% [markdown]
# # ***Without Encoding***

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
# encoding happend only on cetagorical value
area1=df.Area.unique() #.unique() ->to find unique value
area1
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur'], dtype=object)

# %%
df.Area=df.Area.replace(['Dhaka', 'Ctg', 'Rangpur'],[1,2,3])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     2  191792.06
# 2        153441.51       101145.55  407934.54     3  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     3  166187.94

# %%
#find correlation after replaceing cetagorical value
df.corr()
# Out:
#                  Marketing Spend  Administration  Transport      Area  \
# Marketing Spend         1.000000        0.230437   0.718001  0.037930
# Administration          0.230437        1.000000   0.009402  0.003026
# Transport               0.718001        0.009402   1.000000  0.097937
# Area                    0.037930        0.003026   0.097937  1.000000
# Profit                  0.937948        0.200717   0.781996  0.048471
#
#                    Profit
# Marketing Spend  0.937948
# Administration   0.200717
# Transport        0.781996
# Area             0.048471
# Profit           1.000000

# %% [markdown]
# # ***Label Encoding***

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df1.Area=le.fit_transform(df1.Area)
df1.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %% [markdown]
# # ***Label Encoding using Loop***

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# if multipal column have catagorical value then
#.dtype=> chack data type (if number type)
for col in df2.columns:
  if df2[col].dtype==np.number:
    continue
  else :
    df2[col]=le.fit_transform(df2[col])

# %% [markdown]
# # ***Another way(Label Encoding using Loop)***

# %%
from pandas.core.dtypes.common import is_numeric_dtype

# %%
for i in df3.columns:
  if is_numeric_dtype(df3[i]):
    continue
  else:
    df3[i]=le.fit_transform(df3[i])

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %% [markdown]
# # ***One Hot Encoding***

# %%
dummy=pd.get_dummies(df4['Area'],columns=df4.Area.unique,dtype=int)

# %%
dummy
# Out:
#     Ctg  Dhaka  Rangpur
# 0     0      1        0
# 1     1      0        0
# 2     0      0        1
# 3     0      1        0
# 4     0      0        1
# 5     0      1        0
# 6     1      0        0
# 7     0      0        1
# 8     0      1        0
# 9     1      0        0
# 10    0      0        1
# 11    1      0        0
# 12    0      0        1
# 13    1      0        0
# 14    0      0        1
# 15    0      1        0
# 16    1      0        0
# 17    0      1        0
# 18    0      0        1
# 19    0      1        0
# 20    1      0        0
# 21    0      1        0
# 22    0      0        1
# 23    0      0        1
# 24    0      1        0
# 25    1      0        0
# 26    0      0        1
# 27    0      1        0
# 28    0      0        1
# 29    0      1        0
# 30    0      0        1
# 31    0      1        0
# 32    1      0        0
# 33    0      0        1
# 34    1      0        0
# 35    0      1        0
# 36    0      0        1
# ...

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df4.drop('Area',axis=1,inplace=True)#axis=1 => for column,axis=a => for row

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0        114523.61       136897.80  471784.10  192261.83
# 1        162597.70       151377.59  443898.53  191792.06
# 2        153441.51       101145.55  407934.54  191050.39
# 3        144372.41       118671.85  383199.62  182901.99
# 4        142107.34        91391.77  366168.42  166187.94

# %% [markdown]
# # ***Dummy Variable Trap***(to delete one column)

# %%
dummy = pd.get_dummies(df5['Area'], columns = df5.Area.unique,drop_first=True,dtype=int,prefix="Area")
#drop_first=> first column will drop

# %%
dummy.head()
# Out:
#    Area_Dhaka  Area_Rangpur
# 0           1             0
# 1           0             0
# 2           0             1
# 3           1             0
# 4           0             1

# %%
df6=pd.concat([df4,dummy],axis=1)

# %%
df6.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  Area_Dhaka  \
# 0        114523.61       136897.80  471784.10  192261.83           1
# 1        162597.70       151377.59  443898.53  191792.06           0
# 2        153441.51       101145.55  407934.54  191050.39           0
# 3        144372.41       118671.85  383199.62  182901.99           1
# 4        142107.34        91391.77  366168.42  166187.94           0
#
#    Area_Rangpur
# 0             0
# 1             0
# 2             1
# 3             0
# 4             1

# %% [markdown]
# # ***One Hot Encoding using Loop***

# %%
cols = ['Area']
for col in cols:
  dummy1=pd.get_dummies(df7[col],prefix='Area',drop_first=True,dtype=int)
  df8=pd.concat([df7,dummy1],axis=1).drop(col,axis=1)

# %%
df8.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  Area_Dhaka  \
# 0        114523.61       136897.80  471784.10  192261.83           1
# 1        162597.70       151377.59  443898.53  191792.06           0
# 2        153441.51       101145.55  407934.54  191050.39           0
# 3        144372.41       118671.85  383199.62  182901.99           1
# 4        142107.34        91391.77  366168.42  166187.94           0
#
#    Area_Rangpur
# 0             0
# 1             0
# 2             1
# 3             0
# 4             1

# %% [markdown]
# # ***Ordinal Encoding***

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
city=df9.Area.unique()

# %%
city
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur'], dtype=object)

# %%
df9.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
od = OrdinalEncoder(categories=[city])# OrdinalEncoder we must select the catagory

# %%
encode_values = od.fit_transform(df9[['Area']])

# %%
encode_values
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [0.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [0.],
#        [2.],
#        [0.],
#        [1.],
#        [0.],
#        [2.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [2.],
#        [0.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [1.],
#        [1.],
#        [2.],
#        [1.],
#        [0.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [1.]])

# %%
encoded_values=pd.DataFrame(encode_values,columns=['Area']) #DataFrame => convert into datafram (encoded value to conver into datafram)

# %%
encoded_values.head()
# Out:
#    Area
# 0   0.0
# 1   1.0
# 2   2.0
# 3   0.0
# 4   2.0

# %%
df9=pd.concat([df9.drop("Area",axis=1),encoded_values],axis=1)

# %%
df9.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  Area
# 0        114523.61       136897.80  471784.10  192261.83   0.0
# 1        162597.70       151377.59  443898.53  191792.06   1.0
# 2        153441.51       101145.55  407934.54  191050.39   2.0
# 3        144372.41       118671.85  383199.62  182901.99   0.0
# 4        142107.34        91391.77  366168.42  166187.94   2.0
