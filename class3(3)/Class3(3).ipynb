# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = [8,9,2,10,3,5,7,12,15]

# %%
Q1= np.percentile(dataset,25)

# %%
Q1
# Out:
# np.float64(5.0)

# %%
Q2= np.percentile(dataset,50)

# %%
Q2
# Out:
# np.float64(8.0)

# %%
Q3= np.percentile(dataset,75)

# %%
Q3
# Out:
# np.float64(10.0)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7e675164-586f-44fe-8f62-94d2791c8320" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7e675164-586f-44fe-8f62-94d2791c8320">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.shape
# Out:
# (50, 5)

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()
df4 = df.copy()

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %% [markdown]
# # ***Normalization***

# %%
from sklearn.preprocessing import MinMaxScaler
mn = MinMaxScaler(feature_range=(12,15))

# %%
df1['Marketing Spend'] = mn.fit_transform(df1[['Marketing Spend']])

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        14.077850       136897.80   1.000000    Dhaka  192261.83
# 1        14.950078       151377.59   0.940893      Ctg  191792.06
# 2        14.783954       101145.55   0.864664  Rangpur  191050.39
# 3        14.619409       118671.85   0.812235    Dhaka  182901.99
# 4        14.578313        91391.77   0.776136  Rangpur  166187.94

# %%
df1['Transport'] = mn.fit_transform(df1[['Transport']])

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        14.077850       136897.80  15.000000    Dhaka  192261.83
# 1        14.950078       151377.59  14.822680      Ctg  191792.06
# 2        14.783954       101145.55  14.593991  Rangpur  191050.39
# 3        14.619409       118671.85  14.436705    Dhaka  182901.99
# 4        14.578313        91391.77  14.328407  Rangpur  166187.94

# %% [markdown]
# # ***Standardization***

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913       136897.80  471784.10    Dhaka  192261.83
# 1         1.955860       151377.59  443898.53      Ctg  191792.06
# 2         1.754364       101145.55  407934.54  Rangpur  191050.39
# 3         1.554784       118671.85  383199.62    Dhaka  182901.99
# 4         1.504937        91391.77  366168.42  Rangpur  166187.94

# %%
df2['Marketing Spend'] = ss.fit_transform(df1[['Marketing Spend']])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913       136897.80  471784.10    Dhaka  192261.83
# 1         1.955860       151377.59  443898.53      Ctg  191792.06
# 2         1.754364       101145.55  407934.54  Rangpur  191050.39
# 3         1.554784       118671.85  383199.62    Dhaka  182901.99
# 4         1.504937        91391.77  366168.42  Rangpur  166187.94

# %% [markdown]
# # ***Robust Scaler***

# %%
from sklearn.preprocessing import RobustScaler
rs = RobustScaler()

# %%
df3['Marketing Spend'] = rs.fit_transform(df3[['Marketing Spend']])

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530       136897.80  471784.10    Dhaka  192261.83
# 1         1.452113       151377.59  443898.53      Ctg  191792.06
# 2         1.303634       101145.55  407934.54  Rangpur  191050.39
# 3         1.156567       118671.85  383199.62    Dhaka  182901.99
# 4         1.119836        91391.77  366168.42  Rangpur  166187.94

# %% [markdown]
# # ***Max Absolute Scaler***

# %%
from sklearn.preprocessing import MaxAbsScaler
md = MaxAbsScaler()

# %%
df4['Marketing Spend'] = md.fit_transform(df4[['Marketing Spend']])

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94
